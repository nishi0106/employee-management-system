# %% [markdown]
# # PROJECT

# %%
# project >> GUI 

# GUI Based project

# %% [markdown]
# ## Employee management system

# %%
# create database

# %%
import pymysql
conn=pymysql.connect(user='root',host='localhost',password='your_password')
qur='CREATE DATABASE emp_project_db'
mycur=conn.cursor()
mycur.execute(qur)
mycur.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[1], line 5
#       3 qur='CREATE DATABASE emp_project_db'
#       4 mycur=conn.cursor()
# ----> 5 mycur.execute(qur)
#       6 mycur.close()
#       7 conn.close()
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:575, in Connection.query(self, sql, unbuffered)
#     573     sql = sql.encode(self.encoding, "surrogateescape")
#     574 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 575 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     576 return self._affected_rows
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:826, in Connection._read_query_result(self, unbuffered)
#     824     result.init_unbuffered_query()
#     825 else:
# --> 826     result.read()
#     827 self._result = result
#     828 if result.server_status is not None:
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:1203, in MySQLResult.read(self)
#    1201 def read(self):
#    1202     try:
# -> 1203         first_packet = self.connection._read_packet()
#    1205         if first_packet.is_ok_packet():
#    1206             self._read_ok_packet(first_packet)
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:782, in Connection._read_packet(self, packet_type)
#     780     if self._result is not None and self._result.unbuffered_active is True:
#     781         self._result.unbuffered_active = False
# --> 782     packet.raise_for_error()
#     783 return packet
#
# File ~\anaconda3\Lib\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     217 if DEBUG:
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File ~\anaconda3\Lib\site-packages\pymysql\err.py:150, in raise_mysql_exception(data)
#     148 if errorclass is None:
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# ProgrammingError: (1007, "Can't create database 'emp_project_db'; database exists")

# %%
import pymysql
conn=pymysql.connect(user='root',host='localhost',password='nisha@2004',database='emp_project_db')
qur='''CREATE TABLE emp (
    emp_id VARCHAR(10) PRIMARY KEY,
    emp_name VARCHAR(100),
    mob_no VARCHAR(15),
    dept VARCHAR(50),
    emp_salary VARCHAR(20)
)'''
mycur=conn.cursor()
mycur.execute(qur)
mycur.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[2], line 11
#       3 qur='''CREATE TABLE emp (
#       4     emp_id VARCHAR(10) PRIMARY KEY,
#       5     emp_name VARCHAR(100),
#    (...)
#       8     emp_salary VARCHAR(20)
#       9 )'''
#      10 mycur=conn.cursor()
# ---> 11 mycur.execute(qur)
#      12 mycur.close()
#      13 conn.close()
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:575, in Connection.query(self, sql, unbuffered)
#     573     sql = sql.encode(self.encoding, "surrogateescape")
#     574 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 575 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     576 return self._affected_rows
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:826, in Connection._read_query_result(self, unbuffered)
#     824     result.init_unbuffered_query()
#     825 else:
# --> 826     result.read()
#     827 self._result = result
#     828 if result.server_status is not None:
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:1203, in MySQLResult.read(self)
#    1201 def read(self):
#    1202     try:
# -> 1203         first_packet = self.connection._read_packet()
#    1205         if first_packet.is_ok_packet():
#    1206             self._read_ok_packet(first_packet)
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:782, in Connection._read_packet(self, packet_type)
#     780     if self._result is not None and self._result.unbuffered_active is True:
#     781         self._result.unbuffered_active = False
# --> 782     packet.raise_for_error()
#     783 return packet
#
# File ~\anaconda3\Lib\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     217 if DEBUG:
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File ~\anaconda3\Lib\site-packages\pymysql\err.py:150, in raise_mysql_exception(data)
#     148 if errorclass is None:
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# OperationalError: (1050, "Table 'emp' already exists")

# %%
# GUI

# %%
import pymysql
from tkinter import * 
from tkinter import messagebox
from tkinter import ttk

win = Tk()
win.title('EMPLOYEE MANAGEMENT SYSTEM')
win.config(bg='grey')
win.geometry('800x600') 

def show():
    conn=pymysql.connect(user='root',host='localhost',password='nisha@2004',database='emp_project_db')
    qur=f'SELECT * FROM emp'
    mycur=conn.cursor()
    mycur.execute(qur)
    tup1=mycur.fetchall()
    for i in tup1:
        treev.insert('',END,values=(i[0],i[1],i[2],i[3],i[4]))
    mycur.close()
    
def add():
    emp_id=id1.get()
    emp_name=n1.get()
    mob_no=m1.get()
    dept=d1.get()
    emp_salary=s1.get()
    if emp_id=='' or emp_name=='' or mob_no=='' or dept=='' or emp_salary=='':
        messagebox.showinfo('info','All fields are compuslory !!!')
    else:
        conn=pymysql.connect(user='root',host='localhost',password='nisha@2004',database='emp_project_db')
        qur=f'INSERT INTO emp VALUES("{emp_id}","{emp_name}","{mob_no}","{dept}","{emp_salary}")'
        mycur=conn.cursor()
        mycur.execute(qur)
        conn.commit()
        mycur.close()
        conn.close()
        messagebox.showinfo('info','Data is inserted successfully')
        id1.set('')
        n1.set('')
        m1.set('')
        d1.set('')
        s1.set('')
        var2.set('')
        

def salary():
    root=Tk()
    root.title('SALARY MANAGEMENT SYSTEM')
    root.config(bg='gray')
    root.geometry('800x600')
    def show_sal():
        sal_data=e8.get()
        if sal_data=='':
            messagebox.showinfo('info','All fields are compulsory!!')
        else:
            conn=pymysql.connect(user='root',host='localhost',password='nisha@2004',database='emp_project_db')
            qur=f'SELECT emp_name,emp_salary FROM emp WHERE emp_id="{sal_data}"'
            mycur=conn.cursor()
            mycur.execute(qur)
            tup1=mycur.fetchone()
            mystr=f'Salary of {tup1[0]} is {tup1[1]} Rs.'
            l9.config(text=mystr)
            mycur.close()
            conn.close()
            
        
    l8=Label(root,text='ENTER ID>>',bg='white',fg='black',width=20,bd=5,
        relief='ridge',font=('times new roman',12,'bold'))
    l8.place(x=100,y=80)
    
    var3=StringVar()
    e8=Entry(root,textvariable=var3,bg='white',fg='black',width=40,bd=5,
            relief='ridge',font=('times new roman',12,'bold'))
    e8.place(x=310,y=80)
    
    b8=Button(root,text='SHOW SALARY',width=14,command=show_sal,bd=5,relief='ridge',
              bg='black',fg='white',font=('times new roman',11,'bold'))
    b8.place(x=200,y=120)

    l9=Label(root,text='Result is here >>',bg='white',fg='black',width=40,bd=5,height=5,
        relief='ridge',font=('times new roman',14,'bold'))
    l9.place(x=100,y=200)
    
    root.mainloop()

def delete() :
    del_data=var1.get()
    conn=pymysql.connect(user='root',host='localhost',password='nisha@2004',database='emp_project_db')
    qur=f'DELETE FROM emp WHERE emp_id="{del_data}"'
    mycur=conn.cursor()
    mycur.execute(qur)
    conn.commit()
    mycur.close()
    conn.close()
    messagebox.showinfo('info',f'Record of{del_data} id is Deleted successfully')
    var1.set('')
def select():
    up_data=var2.get()
    conn=pymysql.connect(user='root',host='localhost',password='nisha@2004',database='emp_project_db')
    qur=f'SELECT * FROM emp WHERE emp_id="{up_data}"'
    mycur=conn.cursor()
    mycur.execute(qur)
    tup1=mycur.fetchone()
    e1.insert(0,tup1[0])
    e2.insert(0,tup1[1])
    e3.insert(0,tup1[2])
    e4.delete(0,END)
    e4.insert(0,tup1[3])
    e5.insert(0,tup1[4])
    mycur.close()
    conn.close()
    

def update():
    emp_id=id1.get()
    emp_name=n1.get()
    mob_no=m1.get()
    dept=d1.get()
    emp_salary=s1.get()
    if emp_id=='' or emp_name=='' or mob_no=='' or dept=='' or emp_salary=='':
        messagebox.showinfo('info','All fields are compuslory !!!')
    else:
        conn=pymysql.connect(user='root',host='localhost',password='nisha@2004',database='emp_project_db')
        qur=f''' UPDATE emp SET emp_id="{emp_id}",emp_name="{emp_name}",mob_no="{mob_no}",dept="{dept}",
        emp_salary="{emp_salary}" WHERE emp_id="{emp_id}"
        '''
        mycur=conn.cursor()
        mycur.execute(qur)
        conn.commit()
        mycur.close()
        conn.close()
        messagebox.showinfo('info','Data is updated successfully')
        id1.set('')
        n1.set('')
        m1.set('')
        d1.set('')
        s1.set('')
        
def clear():
    treev.delete(*treev.get_children())
    
# main label

l0=Label(win,text='EMPLOYEE MANAGEMENT SYSTEM' , width=40,bd=5,relief='ridge',bg='white',fg='black',
         font=('times new roman',18,'bold'))

l0.place(x=268,y=20)


# emp_id >> name and entry

l1=Label(win,text='EMPLOYEE ID' ,bd=5,
         relief='ridge',bg='white',fg='black',width=20,font=('times new roman',12,'bold'))

l1.place(x=100,y=80)

id1=StringVar()
e1=Entry(win,textvariable=id1,bd=5,relief='ridge',bg='white',fg='black',width=40,font=('times new roman',12,'bold'))
e1.place(x=310,y=80)

# emp_name > label an entry

l2=Label(win,text='EMPLOYEE NAME' ,bd=5,
         relief='ridge',bg='white',fg='black',width=20,font=('times new roman',12,'bold'))

l2.place(x=100,y=120)

n1=StringVar()
e2=Entry(win,textvariable=n1,bd=5,relief='ridge',bg='white',fg='black',width=40,font=('times new roman',12,'bold'))

e2.place(x=310,y=120)

# mob_num >> label entry

l3=Label(win,text='MOBILE NUMBER',bg='white',fg='black',width=20,bd=5,
        relief='ridge',font=('times new roman',12,'bold'))
l3.place(x=100,y=160)

m1=StringVar()
e3=Entry(win,textvariable=m1,bg='white',fg='black',width=40,bd=5,
        relief='ridge',font=('times new roman',12,'bold'))
e3.place(x=310,y=160)

# dept >> label entry

l4=Label(win,text='DEPARTMENT',bg='white',fg='black',width=20,bd=5,
        relief='ridge',font=('times new roman',12,'bold'))
l4.place(x=100,y=200)

d1=StringVar()
e4=ttk.Combobox(win,textvariable=d1,width=38,font=('times new roman',12,'bold'))
e4.place(x=310,y=200,height=30)
e4['values']=('R&D','Marketing','Production','HR')
e4.current(0)

# salary >> label ,entry

l5=Label(win,text='SALARY',bg='white',fg='black',width=20,bd=5,
        relief='ridge',font=('times new roman',12,'bold'))
l5.place(x=100,y=240)

s1=StringVar()
e5=Entry(win,textvariable=s1,bg='white',fg='black',width=40,bd=5,
        relief='ridge',font=('times new roman',12,'bold'))
e5.place(x=310,y=240)

# buttons >> four
# ADD SHOW EXIST SALARY

b1=Button(win,text='SHOW',width=12,command=show,bd=5,relief='ridge',
          bg='black',fg='white',font=('times new roman',11,'bold'))
b1.place(x=180,y=300)

b2=Button(win,text='ADD',width=12,command=add,bd=5,relief='ridge',
          bg='black',fg='white',font=('times new roman',11,'bold'))
b2.place(x=410,y=300)

b3=Button(win,text='EXIT',width=12,command=win.destroy,bd=5,relief='ridge',
          bg='black',fg='white',font=('times new roman',11,'bold'))
b3.place(x=180,y=340)

b4=Button(win,text='SALARY',width=12,command=salary,bd=5,relief='ridge',
          bg='black',fg='white',font=('times new roman',11,'bold'))
b4.place(x=410,y=340)

# DELETE INTERFACE 
# label >> entry >> button
# l6 e6 b5

l6=Label(win,text='ENTER ID>>',bg='white',fg='black',width=20,bd=5,
        relief='ridge',font=('times new roman',12,'bold'))
l6.place(x=100,y=400)

var1=StringVar()
e6=Entry(win,textvariable=var1,bg='white',fg='black',width=40,bd=5,
        relief='ridge',font=('times new roman',12,'bold'))
e6.place(x=310,y=400)

b5=Button(win,text='DELETE',width=12,command=delete,bd=5,relief='ridge',
          bg='black',fg='white',font=('times new roman',11,'bold'))
b5.place(x=310,y=440)


# update interface

# label , entry , and two buttons

# l7 e7 b6 b7

l7=Label(win,text='ENTER ID>>',bg='white',fg='black',width=20,bd=5,
        relief='ridge',font=('times new roman',12,'bold'))
l7.place(x=100,y=490)

var2=StringVar()
e7=Entry(win,textvariable=var2,bg='white',fg='black',width=40,bd=5,
        relief='ridge',font=('times new roman',12,'bold'))
e7.place(x=310,y=490)

b6=Button(win,text='SELECT',width=12,command=select,bd=5,relief='ridge',
          bg='black',fg='white',font=('times new roman',11,'bold'))
b6.place(x=200,y=540)

b7=Button(win,text='UPDATE',width=12,command=update,bd=5,relief='ridge',
          bg='black',fg='white',font=('times new roman',11,'bold'))
b7.place(x=350,y=540)

# tree view 
treev=ttk.Treeview(win,height=23)
treev.place(x=700,y=80,width=565)

treev["columns"] = ("1","2","3","4","5")
treev['show'] = 'headings'

treev.column("1", width = 90, anchor = 'c')
treev.column("2", width = 90, anchor = 'se')
treev.column("3", width = 90, anchor = 'se')
treev.column("4", width = 90, anchor = 'se')
treev.column("5", width = 90, anchor = 'se')

treev.heading("1",text ="Emp_ID")
treev.heading("2",text ="Emp_Name")
treev.heading("3",text ="Mob No")
treev.heading("4",text ="Dept")
treev.heading("5",text ="Salary")

# clear

b8=Button(win,text='CLEAR',width=12,command=clear,bd=5,relief='ridge',
          bg='black',fg='white',font=('times new roman',11,'bold'))
b8.place(x=910,y=570)

win.mainloop()
